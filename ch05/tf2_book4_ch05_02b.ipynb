# %% [markdown]
# # 5.2
# ## TensorFlow スタイルによるプログラミング

# %%
# 5-02-12 CIFAR-10 データセットの読み込み
# p.299

from tensorflow import keras
from tensorflow.keras import datasets

(x_train, t_train), (x_test, t_test) = datasets.cifar10.load_data()

print(x_train.shape, t_train.shape)
print(x_test.shape, t_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
# 5-02-13 CNNモデルの定義
# p.299

from tensorflow.keras import layers

class CNN(keras.Model):
    def __init__(self, output_dim):
        super().__init__()
        weight_decay = 1e-4
        self.c1 = layers.Conv2D(
            filters=32,
            kernel_size=(3, 3),
            padding='same',
            input_shape=x_train[0].shape,
            kernel_regularizer=keras.regularizers.l2(weight_decay), 
            activation='relu'
            )
        self.p1 = layers.MaxPooling2D(pool_size=(2, 2))
        self.c2 = layers.Conv2D(
            filters=128,
            kernel_size=(3, 3),
            padding='same',
            kernel_regularizer=keras.regularizers.l2(weight_decay), 
            activation='relu'
            )
        self.p2 = layers.MaxPooling2D(pool_size=(2, 2))
        self.c3 = layers.Conv2D(
            filters=256,
            kernel_size=(3, 3),
            padding='same',
            kernel_regularizer=keras.regularizers.l2(weight_decay), 
            activation='relu'
            )
        self.p3 = layers.MaxPooling2D(pool_size=(2, 2))
        self.f1 = layers.Flatten()
        self.d1 = layers.Dropout(0.4)
        self.l1 = layers.Dense(512, activation='relu')
        self.l2 = layers.Dense(10, activation='softmax')
        self.ls = [ self.c1, self.p1, self.c2, self.p2, self.c3, 
                  self.p3, self.f1, self.d1, self.l1, self.l2 ]
        
    def call(self, x):
        for layer in self.ls:
            x = layer(x)
        return x

# %%
# 5-02-14 損失関数の定義
# p.303

cce = keras.losses.SparseCategoricalCrossentropy()

def loss(t, y):
    return cce(t, y)

# %%
# 5-02-15 オプティマイザー、損失と精度の記録
# p.303

optimizer = keras.optimizers.SGD(learning_rate=0.1)

train_loss = keras.metrics.Mean()
train_acc = keras.metrics.SparseCategoricalAccuracy()
val_loss = keras.metrics.Mean()
val_acc = keras.metrics.SparseCategoricalAccuracy()

# %%
# 5-02-16 パラメータの更新処理
# p.304

import tensorflow as tf

@tf.function
def train_step(x, t):
    with tf.GradientTape() as tape:
        outputs = model(x)
        tmp_loss = loss(t, outputs)
    grads = tape.gradient(tmp_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    train_loss(tmp_loss)
    train_acc(t, outputs)

# %%
# 5-02-17 検証データでモデルを評価する
# p.305

def val_step(x, t):
    preds = model(x)
    tmp_loss = loss(t, preds)
    val_loss(tmp_loss)
    val_acc(t, preds)

# %% [markdown]
# ### 学習の実行

# %%
# 5-02-18 訓練データを拡張処理して学習を行う
# p.308
# [自分へのメモ] %%time で実行時間を測るのは別のcellで行う

from sklearn.utils import shuffle

epochs = 100
batch_size = 64
train_steps = len(x_train) * 0.8 / batch_size
val_steps = len(x_train) * 0.2 / batch_size

model = CNN(10)

datagen = keras.preprocessing.image.ImageDataGenerator(
    rescale=1.0/255.0,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2
)

training_generator = datagen.flow(
    x_train, 
    t_train,
    batch_size=batch_size,
    subset='training'
    )

validation_generator = datagen.flow(
    x_train,
    t_train,
    batch_size=batch_size,
    subset='validation'
    )

# %%
# %%time

for epoch in range(epochs):
    step_counter = 0
    for x_batch, t_batch in training_generator:
        train_step(x_batch, t_batch)
        step_counter += 1
        if step_counter >= train_steps:
            break
    v_step_counter = 0
    for x_val_batch, t_val_batch in validation_generator:
        val_step(x_val_batch, t_val_batch)
        v_step_counter += 1
        if v_step_counter >= val_steps:
            break
    # 1 epoch 毎の結果を出力する
    print(f'epoch: {epoch+1}  '
          f'train_loss: {train_loss.result():.4f}  '
          f'train_acc: {train_acc.result():.4f}  '
          f'val_loss: {val_loss.result():.4f}  '
          f'val_acc: {val_acc.result():.4f}'
         )
# Out:
# epoch: 1  train_loss: 1.9456  train_acc: 0.2958  val_loss: 1.7882  val_acc: 0.3468
# epoch: 2  train_loss: 1.7338  train_acc: 0.3746  val_loss: 1.5983  val_acc: 0.4252
# epoch: 3  train_loss: 1.6072  train_acc: 0.4207  val_loss: 1.4879  val_acc: 0.4649
# epoch: 4  train_loss: 1.5137  train_acc: 0.4557  val_loss: 1.4105  val_acc: 0.4956
# epoch: 5  train_loss: 1.4376  train_acc: 0.4848  val_loss: 1.3438  val_acc: 0.5206
# epoch: 6  train_loss: 1.3729  train_acc: 0.5092  val_loss: 1.2910  val_acc: 0.5395
# epoch: 7  train_loss: 1.3171  train_acc: 0.5303  val_loss: 1.2420  val_acc: 0.5572
# epoch: 8  train_loss: 1.2674  train_acc: 0.5488  val_loss: 1.2070  val_acc: 0.5696
# epoch: 9  train_loss: 1.2232  train_acc: 0.5652  val_loss: 1.1800  val_acc: 0.5807
# epoch: 10  train_loss: 1.1838  train_acc: 0.5796  val_loss: 1.1463  val_acc: 0.5931
# epoch: 11  train_loss: 1.1478  train_acc: 0.5928  val_loss: 1.1160  val_acc: 0.6041
# epoch: 12  train_loss: 1.1152  train_acc: 0.6047  val_loss: 1.0889  val_acc: 0.6140
# epoch: 13  train_loss: 1.0851  train_acc: 0.6156  val_loss: 1.0653  val_acc: 0.6227
# epoch: 14  train_loss: 1.0569  train_acc: 0.6257  val_loss: 1.0485  val_acc: 0.6292
# epoch: 15  train_loss: 1.0310  train_acc: 0.6351  val_loss: 1.0319  val_acc: 0.6357
# epoch: 16  train_loss: 1.0068  train_acc: 0.6437  val_loss: 1.0154  val_acc: 0.6418
# epoch: 17  train_loss: 0.9840  train_acc: 0.6519  val_loss: 0.9978  val_acc: 0.6486
# epoch: 18  train_loss: 0.9627  train_acc: 0.6596  val_loss: 0.9841  val_acc: 0.6537
# epoch: 19  train_loss: 0.9428  train_acc: 0.6666  val_loss: 0.9710  val_acc: 0.6582
# epoch: 20  train_loss: 0.9238  train_acc: 0.6735  val_loss: 0.9608  val_acc: 0.6621
# epoch: 21  train_loss: 0.9056  train_acc: 0.6800  val_loss: 0.9506  val_acc: 0.6659
# epoch: 22  train_loss: 0.8885  train_acc: 0.6862  val_loss: 0.9415  val_acc: 0.6697
# epoch: 23  train_loss: 0.8721  train_acc: 0.6920  val_loss: 0.9328  val_acc: 0.6731
# epoch: 24  train_loss: 0.8564  train_acc: 0.6975  val_loss: 0.9235  val_acc: 0.6767
# epoch: 25  train_loss: 0.8413  train_acc: 0.7029  val_loss: 0.9153  val_acc: 0.6799
# epoch: 26  train_loss: 0.8268  train_acc: 0.7081  val_loss: 0.9079  val_acc: 0.6830
# epoch: 27  train_loss: 0.8130  train_acc: 0.7130  val_loss: 0.9004  val_acc: 0.6860
# epoch: 28  train_loss: 0.7996  train_acc: 0.7177  val_loss: 0.8934  val_acc: 0.6890
# epoch: 29  train_loss: 0.7867  train_acc: 0.7223  val_loss: 0.8873  val_acc: 0.6917
# epoch: 30  train_loss: 0.7742  train_acc: 0.7267  val_loss: 0.8820  val_acc: 0.6941
# epoch: 31  train_loss: 0.7624  train_acc: 0.7308  val_loss: 0.8777  val_acc: 0.6963
# epoch: 32  train_loss: 0.7511  train_acc: 0.7349  val_loss: 0.8724  val_acc: 0.6985
# epoch: 33  train_loss: 0.7400  train_acc: 0.7388  val_loss: 0.8687  val_acc: 0.7005
# epoch: 34  train_loss: 0.7291  train_acc: 0.7426  val_loss: 0.8644  val_acc: 0.7025
# epoch: 35  train_loss: 0.7187  train_acc: 0.7463  val_loss: 0.8603  val_acc: 0.7045
# epoch: 36  train_loss: 0.7086  train_acc: 0.7499  val_loss: 0.8566  val_acc: 0.7064
# epoch: 37  train_loss: 0.6988  train_acc: 0.7534  val_loss: 0.8531  val_acc: 0.7082
# epoch: 38  train_loss: 0.6893  train_acc: 0.7567  val_loss: 0.8494  val_acc: 0.7101
# epoch: 39  train_loss: 0.6801  train_acc: 0.7600  val_loss: 0.8460  val_acc: 0.7119
# epoch: 40  train_loss: 0.6712  train_acc: 0.7632  val_loss: 0.8438  val_acc: 0.7134
# epoch: 41  train_loss: 0.6627  train_acc: 0.7661  val_loss: 0.8410  val_acc: 0.7150
# epoch: 42  train_loss: 0.6542  train_acc: 0.7691  val_loss: 0.8385  val_acc: 0.7167
# epoch: 43  train_loss: 0.6460  train_acc: 0.7721  val_loss: 0.8357  val_acc: 0.7181
# epoch: 44  train_loss: 0.6381  train_acc: 0.7749  val_loss: 0.8348  val_acc: 0.7194
# epoch: 45  train_loss: 0.6304  train_acc: 0.7776  val_loss: 0.8333  val_acc: 0.7207
# epoch: 46  train_loss: 0.6229  train_acc: 0.7803  val_loss: 0.8314  val_acc: 0.7221
# epoch: 47  train_loss: 0.6157  train_acc: 0.7829  val_loss: 0.8296  val_acc: 0.7235
# epoch: 48  train_loss: 0.6086  train_acc: 0.7853  val_loss: 0.8281  val_acc: 0.7247
# epoch: 49  train_loss: 0.6017  train_acc: 0.7878  val_loss: 0.8273  val_acc: 0.7257
# epoch: 50  train_loss: 0.5949  train_acc: 0.7902  val_loss: 0.8262  val_acc: 0.7267
# epoch: 51  train_loss: 0.5883  train_acc: 0.7925  val_loss: 0.8256  val_acc: 0.7277
# epoch: 52  train_loss: 0.5819  train_acc: 0.7948  val_loss: 0.8251  val_acc: 0.7286
# epoch: 53  train_loss: 0.5758  train_acc: 0.7970  val_loss: 0.8247  val_acc: 0.7295
# epoch: 54  train_loss: 0.5697  train_acc: 0.7992  val_loss: 0.8243  val_acc: 0.7304
# epoch: 55  train_loss: 0.5637  train_acc: 0.8013  val_loss: 0.8241  val_acc: 0.7313
# epoch: 56  train_loss: 0.5579  train_acc: 0.8033  val_loss: 0.8233  val_acc: 0.7322
# epoch: 57  train_loss: 0.5522  train_acc: 0.8053  val_loss: 0.8221  val_acc: 0.7331
# epoch: 58  train_loss: 0.5468  train_acc: 0.8073  val_loss: 0.8215  val_acc: 0.7341
# epoch: 59  train_loss: 0.5414  train_acc: 0.8092  val_loss: 0.8212  val_acc: 0.7349
# epoch: 60  train_loss: 0.5360  train_acc: 0.8111  val_loss: 0.8214  val_acc: 0.7357
# epoch: 61  train_loss: 0.5309  train_acc: 0.8129  val_loss: 0.8219  val_acc: 0.7364
# epoch: 62  train_loss: 0.5257  train_acc: 0.8148  val_loss: 0.8216  val_acc: 0.7372
# epoch: 63  train_loss: 0.5209  train_acc: 0.8165  val_loss: 0.8219  val_acc: 0.7378
# epoch: 64  train_loss: 0.5162  train_acc: 0.8181  val_loss: 0.8216  val_acc: 0.7385
# epoch: 65  train_loss: 0.5114  train_acc: 0.8198  val_loss: 0.8212  val_acc: 0.7393
# epoch: 66  train_loss: 0.5068  train_acc: 0.8215  val_loss: 0.8217  val_acc: 0.7399
# epoch: 67  train_loss: 0.5023  train_acc: 0.8231  val_loss: 0.8217  val_acc: 0.7406
# epoch: 68  train_loss: 0.4979  train_acc: 0.8246  val_loss: 0.8218  val_acc: 0.7412
# epoch: 69  train_loss: 0.4935  train_acc: 0.8262  val_loss: 0.8215  val_acc: 0.7418
# epoch: 70  train_loss: 0.4893  train_acc: 0.8277  val_loss: 0.8218  val_acc: 0.7425
# epoch: 71  train_loss: 0.4851  train_acc: 0.8292  val_loss: 0.8220  val_acc: 0.7430
# epoch: 72  train_loss: 0.4810  train_acc: 0.8306  val_loss: 0.8221  val_acc: 0.7436
# epoch: 73  train_loss: 0.4769  train_acc: 0.8321  val_loss: 0.8223  val_acc: 0.7441
# epoch: 74  train_loss: 0.4731  train_acc: 0.8334  val_loss: 0.8226  val_acc: 0.7447
# epoch: 75  train_loss: 0.4692  train_acc: 0.8348  val_loss: 0.8225  val_acc: 0.7453
# epoch: 76  train_loss: 0.4654  train_acc: 0.8362  val_loss: 0.8223  val_acc: 0.7459
# epoch: 77  train_loss: 0.4616  train_acc: 0.8375  val_loss: 0.8224  val_acc: 0.7465
# epoch: 78  train_loss: 0.4580  train_acc: 0.8388  val_loss: 0.8228  val_acc: 0.7469
# epoch: 79  train_loss: 0.4544  train_acc: 0.8401  val_loss: 0.8237  val_acc: 0.7474
# epoch: 80  train_loss: 0.4508  train_acc: 0.8413  val_loss: 0.8240  val_acc: 0.7479
# epoch: 81  train_loss: 0.4474  train_acc: 0.8426  val_loss: 0.8248  val_acc: 0.7484
# epoch: 82  train_loss: 0.4440  train_acc: 0.8438  val_loss: 0.8258  val_acc: 0.7488
# epoch: 83  train_loss: 0.4407  train_acc: 0.8450  val_loss: 0.8264  val_acc: 0.7492
# epoch: 84  train_loss: 0.4374  train_acc: 0.8462  val_loss: 0.8277  val_acc: 0.7496
# epoch: 85  train_loss: 0.4342  train_acc: 0.8473  val_loss: 0.8287  val_acc: 0.7499
# epoch: 86  train_loss: 0.4310  train_acc: 0.8484  val_loss: 0.8296  val_acc: 0.7503
# epoch: 87  train_loss: 0.4278  train_acc: 0.8496  val_loss: 0.8310  val_acc: 0.7507
# epoch: 88  train_loss: 0.4248  train_acc: 0.8506  val_loss: 0.8315  val_acc: 0.7511
# epoch: 89  train_loss: 0.4218  train_acc: 0.8517  val_loss: 0.8320  val_acc: 0.7515
# epoch: 90  train_loss: 0.4188  train_acc: 0.8528  val_loss: 0.8334  val_acc: 0.7518
# epoch: 91  train_loss: 0.4159  train_acc: 0.8538  val_loss: 0.8342  val_acc: 0.7522
# epoch: 92  train_loss: 0.4130  train_acc: 0.8548  val_loss: 0.8347  val_acc: 0.7526
# epoch: 93  train_loss: 0.4102  train_acc: 0.8558  val_loss: 0.8353  val_acc: 0.7530
# epoch: 94  train_loss: 0.4074  train_acc: 0.8568  val_loss: 0.8361  val_acc: 0.7534
# epoch: 95  train_loss: 0.4048  train_acc: 0.8578  val_loss: 0.8366  val_acc: 0.7538
# epoch: 96  train_loss: 0.4021  train_acc: 0.8587  val_loss: 0.8371  val_acc: 0.7541
# epoch: 97  train_loss: 0.3995  train_acc: 0.8596  val_loss: 0.8382  val_acc: 0.7544
# epoch: 98  train_loss: 0.3969  train_acc: 0.8606  val_loss: 0.8391  val_acc: 0.7549
# epoch: 99  train_loss: 0.3944  train_acc: 0.8615  val_loss: 0.8400  val_acc: 0.7553
# epoch: 100  train_loss: 0.3919  train_acc: 0.8624  val_loss: 0.8408  val_acc: 0.7556
# CPU times: user 46min 45s, sys: 24.4 s, total: 47min 9s
# Wall time: 46min 47s

# %%
# 5-02-19 テストデータで学習済みモデルを評価する
# p.310

test_loss = keras.metrics.Mean()
test_acc = keras.metrics.SparseCategoricalAccuracy()

def test_step(x, t):
    preds = model(x)
    tmp_loss = loss(t, preds)
    test_loss(tmp_loss)
    test_acc(t, preds)

x_test = x_test.astype('float32') / 255
test_step(x_test, t_test)

print(f'test_loss: {test_loss.result():.4f}  test_acc: {test_acc.result():.4f}')
# Out:
# test_loss: 0.8711  test_acc: 0.8203
