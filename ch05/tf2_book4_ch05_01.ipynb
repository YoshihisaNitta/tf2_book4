# %% [markdown]
# # 5.1 tf.keras.layers.Conv2D による CNN の実装
#
# <code>
# tf.keras.layers.Conv2D(
#     filters,
#     kernel-size,
#     stride=(1,1),
#     padding='valid',
#     data_format=None,
#     dilation_rate=(1,1),
#     groups=1,
#     activation=None,
#     use_bias=True,
#     kernel_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     bias_constraint=None
#     )
# </code>
#
# <code>
# tf.keras.layers.MaxPool2D(
#     pool_size=(2,2),
#     strides=None,
#     padding='valid',
#     data_format=None
#     )
# </code>
#
# <code>
# tf.keras.layers.Dropout(
#     rate,
#     noise_shape=None,
#     seed=None
#     )
# </code>

# %%
# 5-01-1 Fashion-MNIST データの読み込みと前処理
# p.252
# [自分へのメモ]前処理したデータは、変数に上書きせずに、別の変数に保存する

import tensorflow as tf
from tensorflow  import keras

(x_train, t_train), (x_test, t_test) = tf.keras.datasets.fashion_mnist.load_data()

x_train_norm = x_train.astype('float32') / 255.
x_test_norm = x_test.astype('float32') / 255.

x_train_rs = x_train_norm.reshape(-1, 28, 28, 1)
x_test_rs = x_test_norm.reshape(-1, 28, 28, 1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# 5-01-2 CNN モデルを生成するクラス
# p.259

class CNN(tf.keras.Model):
    
    def __init__(self, output_dim):
        super().__init__()
        weight_decay = 1e-4
        self.c1 = tf.keras.layers.Conv2D(
            filters=64,
            kernel_size=(3,3),
            padding='same',
            input_shape=x_train[0].shape,
            kernel_regularizer=tf.keras.regularizers.l2(weight_decay),
            activation='relu'
        )
        self.c2 = tf.keras.layers.Conv2D(
            filters=32,
            kernel_size=(3,3),
            padding='same',
            kernel_regularizer=tf.keras.regularizers.l2(weight_decay),
            activation='relu'
        )
        self.p1 = tf.keras.layers.MaxPooling2D(
            pool_size=(2,2)
        )
        self.c3 = tf.keras.layers.Conv2D(
            filters=16,
            kernel_size=(3,3),
            padding='same',
            kernel_regularizer=tf.keras.regularizers.l2(weight_decay),
            activation='relu'
        )
        self.p2 = tf.keras.layers.MaxPooling2D(
            pool_size=(2,2)
        )
        self.d1 = tf.keras.layers.Dropout(0.4)
        self.f1 = tf.keras.layers.Flatten()
        self.l1 = tf.keras.layers.Dense(
            128,
            activation='relu'
        )
        self.l2 = tf.keras.layers.Dense(
            output_dim,
            activation='softmax'
        )
        self.ls = [ self.c1, self.c2, self.p1, self.c3, self.p2, self.d1, self.f1, self.l1, self.l2 ]
        
    def call(self, x):
        for layer in self.ls:
            x = layer(x)
        return x

# %%
# 5-01-3 損失関数の定義
# p.263

cce = keras.losses.SparseCategoricalCrossentropy()

def loss(t, y):
    return cce(t,y)

# %%
# 5-01-4 Stochastic Gradient Descend を使用するオプティマイザー
# p.263

optimizer = keras.optimizers.SGD(learning_rate=0.1)

# 損失を記録するオブジェクト
train_loss = keras.metrics.Mean()

# 精度を記録するオブジェクト
train_acc = keras.metrics.SparseCategoricalAccuracy()

# validationの損失を記録するオブジェクト
val_loss = keras.metrics.Mean()

# validationの精度を記録する
val_acc = keras.metrics.SparseCategoricalAccuracy()

# %%
import tensorflow as tf
# p.264
def train_step(x, t):
    '''
    学習を1回行う
    
    Parameters:
      x (ndarray(float32)): 訓練データ
      t (ndarray(float32)): 正解ラベル
      
    Returns:
      ステップごとのクロスエントロピー誤差
      
      '''
    
    with tf.GradientTape() as tape:
        outputs = model(x)
        tmp_loss = loss(t, outputs)
    grads = tape.gradient(tmp_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    # 損失と精度を記録
    train_loss(tmp_loss)
    train_acc(t, outputs)

# %%
# 5-01-5 検証データによる評価を行う
# p.265
def val_step(x, t):
    preds = model(x)
    tmp_loss = loss(t, preds)
    val_loss(tmp_loss)
    val_acc(t, preds)

# %% [markdown]
# ### 学習の実行

# %%
# 5-01-6 訓練データを検証データを用意する
# p.266
from sklearn.model_selection import train_test_split

x_tr, x_val, t_tr, t_val = train_test_split(x_train_rs, t_train, test_size=0.2)

# %%
print(x_tr.shape)
print(x_val.shape)
print(t_tr.shape)
print(t_val.shape)
# Out:
# (48000, 28, 28, 1)
# (12000, 28, 28, 1)
# (48000,)
# (12000,)

# %%
# 5-01-7 モデルを生成して学習する
# p.266
from sklearn.utils import shuffle

epochs = 100
batch_size = 64
steps = x_tr.shape[0] // batch_size
steps_val = x_val.shape[0] // batch_size

model = CNN(10)

# %%
# 学習を行う
# p.267
# [自分へのメモ] バグだと思われる部分を変更している。

for epoch in range(epochs):
    x_, t_ = shuffle(x_tr, t_tr, random_state=1)
    
    for step in range(steps):
        start = step * batch_size
        end = start + batch_size
        train_step(x_[start:end], t_[start:end])
        
    for step_val in range(steps_val):
        start = step_val * batch_size
        end = start + batch_size
        #val_step(x_[start:end], t_[start:end])   ### !!! Bug
        val_step(x_val[start:end], t_val[start:end])
        
    print(f'epoch: {(epoch+1)} '
          f'train_loss: {train_loss.result():.4f} '
          f'train_acc:{train_acc.result():.4f} '
          f'val_loss: {val_loss.result():.4f} '
          f'val_acc: {val_acc.result():.4f}')
# Out:
# epoch: 1 train_loss: 0.6244 train_acc:0.7717 val_loss: 0.5004 val_acc: 0.8079
# epoch: 2 train_loss: 0.4996 train_acc:0.8172 val_loss: 0.4429 val_acc: 0.8334
# epoch: 3 train_loss: 0.4387 train_acc:0.8389 val_loss: 0.4063 val_acc: 0.8489
# epoch: 4 train_loss: 0.3993 train_acc:0.8531 val_loss: 0.3811 val_acc: 0.8591
# epoch: 5 train_loss: 0.3705 train_acc:0.8636 val_loss: 0.3626 val_acc: 0.8662
# epoch: 6 train_loss: 0.3476 train_acc:0.8719 val_loss: 0.3493 val_acc: 0.8716
# epoch: 7 train_loss: 0.3286 train_acc:0.8788 val_loss: 0.3395 val_acc: 0.8756
# epoch: 8 train_loss: 0.3125 train_acc:0.8847 val_loss: 0.3317 val_acc: 0.8789
# epoch: 9 train_loss: 0.2982 train_acc:0.8900 val_loss: 0.3260 val_acc: 0.8813
# epoch: 10 train_loss: 0.2855 train_acc:0.8946 val_loss: 0.3208 val_acc: 0.8838
# epoch: 11 train_loss: 0.2739 train_acc:0.8989 val_loss: 0.3170 val_acc: 0.8858
# epoch: 12 train_loss: 0.2632 train_acc:0.9029 val_loss: 0.3145 val_acc: 0.8873
# epoch: 13 train_loss: 0.2532 train_acc:0.9068 val_loss: 0.3134 val_acc: 0.8885
# epoch: 14 train_loss: 0.2437 train_acc:0.9104 val_loss: 0.3139 val_acc: 0.8896
# epoch: 15 train_loss: 0.2348 train_acc:0.9137 val_loss: 0.3154 val_acc: 0.8906
# epoch: 16 train_loss: 0.2264 train_acc:0.9168 val_loss: 0.3179 val_acc: 0.8913
# epoch: 17 train_loss: 0.2186 train_acc:0.9197 val_loss: 0.3218 val_acc: 0.8920
# epoch: 18 train_loss: 0.2112 train_acc:0.9224 val_loss: 0.3257 val_acc: 0.8925
# epoch: 19 train_loss: 0.2044 train_acc:0.9250 val_loss: 0.3296 val_acc: 0.8930
# epoch: 20 train_loss: 0.1980 train_acc:0.9274 val_loss: 0.3339 val_acc: 0.8936
# epoch: 21 train_loss: 0.1920 train_acc:0.9296 val_loss: 0.3387 val_acc: 0.8940
# epoch: 22 train_loss: 0.1862 train_acc:0.9317 val_loss: 0.3453 val_acc: 0.8943
# epoch: 23 train_loss: 0.1807 train_acc:0.9337 val_loss: 0.3514 val_acc: 0.8945
# epoch: 24 train_loss: 0.1756 train_acc:0.9355 val_loss: 0.3575 val_acc: 0.8946
# epoch: 25 train_loss: 0.1707 train_acc:0.9373 val_loss: 0.3634 val_acc: 0.8949
# epoch: 26 train_loss: 0.1663 train_acc:0.9389 val_loss: 0.3692 val_acc: 0.8951
# epoch: 27 train_loss: 0.1619 train_acc:0.9405 val_loss: 0.3766 val_acc: 0.8953
# epoch: 28 train_loss: 0.1580 train_acc:0.9420 val_loss: 0.3829 val_acc: 0.8956
# epoch: 29 train_loss: 0.1540 train_acc:0.9434 val_loss: 0.3899 val_acc: 0.8958
# epoch: 30 train_loss: 0.1503 train_acc:0.9448 val_loss: 0.3967 val_acc: 0.8959
# epoch: 31 train_loss: 0.1468 train_acc:0.9461 val_loss: 0.4032 val_acc: 0.8962
# epoch: 32 train_loss: 0.1433 train_acc:0.9474 val_loss: 0.4102 val_acc: 0.8965
# epoch: 33 train_loss: 0.1401 train_acc:0.9486 val_loss: 0.4173 val_acc: 0.8967
# epoch: 34 train_loss: 0.1371 train_acc:0.9497 val_loss: 0.4244 val_acc: 0.8969
# epoch: 35 train_loss: 0.1341 train_acc:0.9508 val_loss: 0.4321 val_acc: 0.8970
# epoch: 36 train_loss: 0.1313 train_acc:0.9518 val_loss: 0.4403 val_acc: 0.8970
# epoch: 37 train_loss: 0.1287 train_acc:0.9527 val_loss: 0.4464 val_acc: 0.8972
# epoch: 38 train_loss: 0.1262 train_acc:0.9537 val_loss: 0.4543 val_acc: 0.8973
# epoch: 39 train_loss: 0.1236 train_acc:0.9546 val_loss: 0.4603 val_acc: 0.8974
# epoch: 40 train_loss: 0.1212 train_acc:0.9555 val_loss: 0.4670 val_acc: 0.8975
# epoch: 41 train_loss: 0.1190 train_acc:0.9564 val_loss: 0.4743 val_acc: 0.8976
# epoch: 42 train_loss: 0.1168 train_acc:0.9571 val_loss: 0.4805 val_acc: 0.8978
# epoch: 43 train_loss: 0.1147 train_acc:0.9579 val_loss: 0.4863 val_acc: 0.8980
# epoch: 44 train_loss: 0.1126 train_acc:0.9587 val_loss: 0.4924 val_acc: 0.8981
# epoch: 45 train_loss: 0.1108 train_acc:0.9594 val_loss: 0.4985 val_acc: 0.8983
# epoch: 46 train_loss: 0.1088 train_acc:0.9601 val_loss: 0.5054 val_acc: 0.8983
# epoch: 47 train_loss: 0.1069 train_acc:0.9608 val_loss: 0.5122 val_acc: 0.8985
# epoch: 48 train_loss: 0.1052 train_acc:0.9614 val_loss: 0.5178 val_acc: 0.8986
# epoch: 49 train_loss: 0.1034 train_acc:0.9621 val_loss: 0.5235 val_acc: 0.8988
# epoch: 50 train_loss: 0.1018 train_acc:0.9627 val_loss: 0.5293 val_acc: 0.8990
# epoch: 51 train_loss: 0.1002 train_acc:0.9633 val_loss: 0.5355 val_acc: 0.8990
# epoch: 52 train_loss: 0.0987 train_acc:0.9639 val_loss: 0.5416 val_acc: 0.8991
# epoch: 53 train_loss: 0.0972 train_acc:0.9644 val_loss: 0.5470 val_acc: 0.8991
# epoch: 54 train_loss: 0.0957 train_acc:0.9650 val_loss: 0.5526 val_acc: 0.8992
# epoch: 55 train_loss: 0.0944 train_acc:0.9655 val_loss: 0.5577 val_acc: 0.8994
# epoch: 56 train_loss: 0.0931 train_acc:0.9660 val_loss: 0.5646 val_acc: 0.8994
# epoch: 57 train_loss: 0.0917 train_acc:0.9665 val_loss: 0.5716 val_acc: 0.8995
# epoch: 58 train_loss: 0.0905 train_acc:0.9669 val_loss: 0.5768 val_acc: 0.8994
# epoch: 59 train_loss: 0.0893 train_acc:0.9674 val_loss: 0.5817 val_acc: 0.8996
# epoch: 60 train_loss: 0.0881 train_acc:0.9678 val_loss: 0.5882 val_acc: 0.8996
# epoch: 61 train_loss: 0.0871 train_acc:0.9682 val_loss: 0.5924 val_acc: 0.8997
# epoch: 62 train_loss: 0.0859 train_acc:0.9686 val_loss: 0.5971 val_acc: 0.8997
# epoch: 63 train_loss: 0.0847 train_acc:0.9691 val_loss: 0.6016 val_acc: 0.8999
# epoch: 64 train_loss: 0.0837 train_acc:0.9695 val_loss: 0.6059 val_acc: 0.8999
# epoch: 65 train_loss: 0.0826 train_acc:0.9699 val_loss: 0.6107 val_acc: 0.9000
# epoch: 66 train_loss: 0.0815 train_acc:0.9703 val_loss: 0.6159 val_acc: 0.9000
# epoch: 67 train_loss: 0.0805 train_acc:0.9706 val_loss: 0.6216 val_acc: 0.9001
# epoch: 68 train_loss: 0.0795 train_acc:0.9710 val_loss: 0.6262 val_acc: 0.9002
# epoch: 69 train_loss: 0.0786 train_acc:0.9714 val_loss: 0.6305 val_acc: 0.9001
# epoch: 70 train_loss: 0.0777 train_acc:0.9717 val_loss: 0.6352 val_acc: 0.9002
# epoch: 71 train_loss: 0.0769 train_acc:0.9720 val_loss: 0.6396 val_acc: 0.9002
# epoch: 72 train_loss: 0.0761 train_acc:0.9723 val_loss: 0.6432 val_acc: 0.9003
# epoch: 73 train_loss: 0.0753 train_acc:0.9726 val_loss: 0.6463 val_acc: 0.9004
# epoch: 74 train_loss: 0.0744 train_acc:0.9729 val_loss: 0.6500 val_acc: 0.9005
# epoch: 75 train_loss: 0.0735 train_acc:0.9733 val_loss: 0.6541 val_acc: 0.9005
# epoch: 76 train_loss: 0.0727 train_acc:0.9736 val_loss: 0.6591 val_acc: 0.9005
# epoch: 77 train_loss: 0.0719 train_acc:0.9739 val_loss: 0.6634 val_acc: 0.9006
# epoch: 78 train_loss: 0.0712 train_acc:0.9741 val_loss: 0.6682 val_acc: 0.9007
# epoch: 79 train_loss: 0.0705 train_acc:0.9744 val_loss: 0.6719 val_acc: 0.9007
# epoch: 80 train_loss: 0.0697 train_acc:0.9747 val_loss: 0.6768 val_acc: 0.9007
# epoch: 81 train_loss: 0.0690 train_acc:0.9749 val_loss: 0.6815 val_acc: 0.9008
# epoch: 82 train_loss: 0.0683 train_acc:0.9752 val_loss: 0.6856 val_acc: 0.9009
# epoch: 83 train_loss: 0.0676 train_acc:0.9755 val_loss: 0.6902 val_acc: 0.9009
# epoch: 84 train_loss: 0.0670 train_acc:0.9757 val_loss: 0.6945 val_acc: 0.9009
# epoch: 85 train_loss: 0.0663 train_acc:0.9760 val_loss: 0.6990 val_acc: 0.9010
# epoch: 86 train_loss: 0.0656 train_acc:0.9762 val_loss: 0.7041 val_acc: 0.9010
# epoch: 87 train_loss: 0.0651 train_acc:0.9764 val_loss: 0.7085 val_acc: 0.9010
# epoch: 88 train_loss: 0.0646 train_acc:0.9766 val_loss: 0.7116 val_acc: 0.9011
# epoch: 89 train_loss: 0.0641 train_acc:0.9768 val_loss: 0.7153 val_acc: 0.9010
# epoch: 90 train_loss: 0.0636 train_acc:0.9770 val_loss: 0.7183 val_acc: 0.9011
# epoch: 91 train_loss: 0.0630 train_acc:0.9772 val_loss: 0.7213 val_acc: 0.9012
# epoch: 92 train_loss: 0.0625 train_acc:0.9774 val_loss: 0.7252 val_acc: 0.9012
# epoch: 93 train_loss: 0.0619 train_acc:0.9776 val_loss: 0.7286 val_acc: 0.9012
# epoch: 94 train_loss: 0.0613 train_acc:0.9778 val_loss: 0.7330 val_acc: 0.9013
# epoch: 95 train_loss: 0.0607 train_acc:0.9780 val_loss: 0.7361 val_acc: 0.9013
# epoch: 96 train_loss: 0.0602 train_acc:0.9782 val_loss: 0.7397 val_acc: 0.9014
# epoch: 97 train_loss: 0.0597 train_acc:0.9784 val_loss: 0.7433 val_acc: 0.9014
# epoch: 98 train_loss: 0.0592 train_acc:0.9786 val_loss: 0.7481 val_acc: 0.9014
# epoch: 99 train_loss: 0.0587 train_acc:0.9788 val_loss: 0.7521 val_acc: 0.9015
# epoch: 100 train_loss: 0.0583 train_acc:0.9789 val_loss: 0.7551 val_acc: 0.9015

# %% [markdown]
# ### テストデータによるモデルの評価

# %%
# 5-01-8 テストデータによるモデルの評価
# p.269

test_loss = keras.metrics.Mean()
test_acc = keras.metrics.SparseCategoricalAccuracy()

def test_step(x, t):
    '''
    Parameters:
      x (ndarray(float32)): test data
      t (ntarray(float32)): label
    '''
    preds = model(x)
    tmp_loss = loss(t, preds)
    test_loss(tmp_loss)
    test_acc(t, preds)

# %%
test_step(x_test_rs, t_test)

print(f'test_loss: {test_loss.result():.4f} '
      f'test_acc: {test_acc.result():.4f}')
# Out:
# test_loss: 1.0943 test_acc: 0.9048
